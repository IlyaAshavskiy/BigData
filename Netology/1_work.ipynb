# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('indicators_data.csv')
df.timestamp=pd.to_datetime(df.timestamp,format="%Y-%m-%d %H:%M:%S")
#2020-10-10 19:00:00
#df.sort_values(by='timestamp')
df_r1=df[df.room_id==1]
df_r2=df[df.room_id==2]
df_r3=df[df.room_id==3]

# %%
df_r1_d11=df_r1[df_r1['timestamp'].dt.day==11] #1 room, 1 day
df_r1_d12=df_r1[df_r1['timestamp'].dt.day==12] #1 room, 2 day
df_r1_d13=df_r1[df_r1['timestamp'].dt.day==13] #1 room, 3 day
df_r2_d11=df_r2[df_r2['timestamp'].dt.day==11] #2 room, 1 day
df_r2_d12=df_r2[df_r2['timestamp'].dt.day==12] #2 room, 2 day
df_r2_d13=df_r2[df_r2['timestamp'].dt.day==13] #2 room, 3 day
df_r3_d11=df_r3[df_r3['timestamp'].dt.day==11] #3 room, 1 day
df_r3_d12=df_r3[df_r3['timestamp'].dt.day==12] #3 room, 2 day
df_r3_d13=df_r3[df_r3['timestamp'].dt.day==13] #3 room, 3 day
#print df_r1_d11.describe()
#print df_r1_d12.describe()
#print df_r1_d13.describe()
#print df_r2_d11.describe()
#print df_r2_d12.describe()
#print df_r2_d13.describe()
#print df_r3_d11.describe()
#print df_r3_d12.describe()
#print df_r3_d13.describe()

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f0',ax=ax,ls="--",ylim=[0,100])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f0',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f0',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f0',ax=ax,ls="--",ylim=[0,100])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f0',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f0',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f0',ax=ax,ls="--",ylim=[0,100])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f0',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f0',ax=ax,color='r')

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f1',ax=ax,ls="--",ylim=[-50,50])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f1',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f1',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f1',ax=ax,ls="--",ylim=[-50,50])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f1',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f1',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f1',ax=ax,ls="--",ylim=[-50,50])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f1',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f1',ax=ax,color='r')

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f2',ax=ax,ls="--",ylim=[200,300])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f2',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f2',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f2',ax=ax,ls="--",ylim=[200,300])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f2',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f2',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f2',ax=ax,ls="--",ylim=[200,300])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f2',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f2',ax=ax,color='r')

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f3',ax=ax,ls="--",ylim=[0,100])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f3',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f3',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f3',ax=ax,ls="--",ylim=[0,100])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f3',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f3',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f3',ax=ax,ls="--",ylim=[0,100])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f3',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f3',ax=ax,color='r')

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f4',ax=ax,ls="--",ylim=[250,350])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f4',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f4',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f4',ax=ax,ls="--",ylim=[250,350])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f4',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f4',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f4',ax=ax,ls="--",ylim=[250,350])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f4',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f4',ax=ax,color='r')

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f5',ax=ax,ls="--",ylim=[200,300])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f5',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f5',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f5',ax=ax,ls="--",ylim=[200,300])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f5',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f5',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f5',ax=ax,ls="--",ylim=[200,300])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f5',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f5',ax=ax,color='r')

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f6',ax=ax,ls="--",ylim=[-50,50])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f6',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f6',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f6',ax=ax,ls="--",ylim=[-50,50])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f6',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f6',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f6',ax=ax,ls="--",ylim=[-50,50])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f6',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f6',ax=ax,color='r')

# %%
fig, ax = plt.subplots()
df_r1_d11[:19].plot(x=df_r1_d13.timestamp,y='f7',ax=ax,ls="--",ylim=[0,100])
df_r1_d12[:19].plot(x=df_r1_d13.timestamp,y='f7',ax=ax,ls="--")
df_r1_d13.plot(x=df_r1_d13.timestamp,y='f7',ax=ax,color='r')
fig, ax = plt.subplots()
df_r2_d11[:19].plot(x=df_r1_d13.timestamp,y='f7',ax=ax,ls="--",ylim=[0,100])
df_r2_d12[:19].plot(x=df_r1_d13.timestamp,y='f7',ax=ax,ls="--")
df_r2_d13.plot(x=df_r1_d13.timestamp,y='f7',ax=ax,color='r')
fig, ax = plt.subplots()
df_r3_d11[:19].plot(x=df_r1_d13.timestamp,y='f7',ax=ax,ls="--",ylim=[0,100])
df_r3_d12[:19].plot(x=df_r1_d13.timestamp,y='f7',ax=ax,ls="--")
df_r3_d13.plot(x=df_r1_d13.timestamp,y='f7',ax=ax,color='r')

# %% [markdown]
# Наибольшая разница по сравнению с остальными комнатами видно на показателе f2 во второй комнате. температура 300![2017-11-17%2017-12-38%201_work%20-%20Mozilla%20Firefox.png](attachment:2017-11-17%2017-12-38%201_work%20-%20Mozilla%20Firefox.png)
